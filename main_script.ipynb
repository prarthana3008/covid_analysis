# %% [markdown]
# <h1><center> COVID-19-Impact-Across-U.S.-States</center></h1>

# %% [markdown]
# <h2><center>Prarthana , Student ID: 800763747</center></h2>

# %% [markdown]
# ## Table of Contents
#
# * [Introduction](#zero-bullet)
# * [Summary](#first- )
# * [Exploratory Data Analysis](#second-bullet)
# * [Conclusion](#third-bullet)
# * [References & Appendix](#fourth-bullet)

# %% [markdown]
# ## Introduction <a class="anchor" id="zero-bullet"></a>

# %% [markdown]
# The COVID-19 pandemic has undeniably reshaped the global landscape, impacting every facet of society. Understanding the trajectory of this unprecedented crisis is paramount for informed decision-making and proactive measures to mitigate its impact. This project delves into an in-depth analysis of COVID-19 data, aiming to unveil trends, patterns, and crucial insights from extensive datasets.
#
# The primary objective of this project is to provide a comprehensive exploration of COVID-19 data through analytical lenses. Leveraging a multifaceted approach, the project combines data visualization and statistical analysis techniques to unravel the intricate dynamics of the pandemic across various dimensions.
#
# The project unfolds in two main phases: data summarization and trend analysis. The initial phase involves data collection, cleaning, and summarization. Here, the focus lies on the rigorous preprocessing and cleansing of raw COVID-19 datasets to prepare a refined dataset suitable for analysis. This phase employs methods encapsulated within the CovidDataSummary class, including data cleaning to handle missing values and data loading for subsequent analysis.

# %% [markdown]
# ## Summary <a class="anchor" id="first-bullet"></a>

# %%
# Importing necessary modules and classes
from covid_analysis.analysis import CovidDataAnalyzer
from covid_analysis.summary import CovidDataSummary

# %%
# Loading data using CovidDataSummary class
file_path = '/Users/prarthanabahuriya/Downloads/us_states_covid19_daily.csv'
covid_summary = CovidDataSummary(file_path)
data = covid_summary.load_data(file_path)

# %%
# Create an instance of CovidDataAnalyzer class
covid_analyzer = CovidDataAnalyzer(data)

# %% [markdown]
# ## Exploratory Data Analysis <a class="anchor" id="second-bullet"></a>

# %%
# Call analysis functions
covid_analyzer.plot_positive_cases_over_time()

# %%
# Call analysis function
covid_analyzer.plot_deaths_over_time()

# %%
# Call analysis functions

covid_analyzer.plot_cases_by_state()
